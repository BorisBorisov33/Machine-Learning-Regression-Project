# %% [markdown]
# House Prices Predictions
# Dataset: https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/overview

# %% [markdown]
# 1. Problem statement (0-10)
# 	* How well is the problem defined?
# 	* Does the research address a real-life problem?
# 	* Does the research solve the correct problem?
#
#
#
# 	* Every problem deals with "real-world" data in some way. Even if you don't use datasets, you'll likely generate some data
# 	* How is the data gathered?
# 	* Is the process statistically valid?
# 	* Is the process of data acquisition, data cleaning, and data manipulation well documented?
# 6. Testing (0-10)
# 	* This can have various meanings: unit testing, hypothesis testing, train / test data set, etc.
# 	* Is the code thoroughly tested?
# 	* Are there any comparisons to other implementations / other articles / previous research?
# 7. Visualization (0-10)
# 	* All kinds of projects employ some visualization: graphical plots, tables, etc.
# 	* Are all visualizations correct (i.e. convey the intended meaning without misleading the intended audience)?
# 	* Are all visualizations clear, and easy to understand?
# 8. Communication (0-10)
# 	* Does the project tell the story correctly?
# 	* Does the project serve the audience it was intended for?

# %% [markdown]
# 2. Layout (0-20)
# 	* Are the document sections structured properly?
# 	* Is the article well-formatted (in terms of readability)?

# %% [markdown]
# 3. Code quality (0-20)
# 	* Is the code well-written? Is the code self-documenting?
# 	* Is the code organized into functions?
# 	* Is the code generally well-structured?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.pipeline import Pipeline

from sklearn.compose import ColumnTransformer
from sklearn.model_selection import GridSearchCV


from sklearn.linear_model import Lasso, Ridge

from sklearn.metrics import mean_absolute_error,r2_score

# %%
train = pd.read_csv('train.csv')
X_test = pd.read_csv('test.csv')

# %%
train.shape
# Out:
# (1460, 81)

# %%
X_test.shape
# Out:
# (1459, 80)

# %% [markdown]
# Divide the data into train and validation set

# %%
attributes = train.drop('SalePrice', axis=1)
labels = train.SalePrice

# %%
X_train,X_valid,y_train,y_valid = train_test_split(
    attributes,
    labels,
    test_size=0.33,
    random_state=33
)

# %%
X_train.shape, X_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((978, 80), (482, 80), (978,), (482,))

# %% [markdown]
# Data cleaning and data manipulation/ Preprocessing\
# Here are all the numerical columns

# %%
X_train.describe().T.iloc[:10]
# Out:
#               count          mean           std     min      25%     50%  \
# Id            978.0    728.608384    422.557427     1.0   370.25   718.5
# MSSubClass    978.0     57.484663     42.772544    20.0    20.00    50.0
# LotFrontage   797.0     68.927227     21.549108    21.0    59.00    68.0
# LotArea       978.0  10452.155419  10424.805743  1300.0  7500.00  9434.5
# OverallQual   978.0      6.077710      1.395304     1.0     5.00     6.0
# OverallCond   978.0      5.573620      1.131660     1.0     5.00     5.0
# YearBuilt     978.0   1971.120654     30.204519  1875.0  1954.00  1972.0
# YearRemodAdd  978.0   1984.713701     20.664891  1950.0  1966.00  1994.0
# MasVnrArea    972.0    103.510288    178.343213     0.0     0.00     0.0
# BsmtFinSF1    978.0    447.878323    437.727161     0.0     0.00   389.0
#
#                    75%       max
# Id             1103.75    1458.0
# MSSubClass       70.00     190.0
# LotFrontage      80.00     182.0
# LotArea       11494.50  215245.0
# OverallQual       7.00      10.0
# OverallCond       6.00       9.0
# YearBuilt      2000.00    2010.0
# YearRemodAdd   2004.00    2010.0
# MasVnrArea      168.00    1378.0
# BsmtFinSF1      727.00    2260.0

# %% [markdown]
# Hereby are all the category/object columns

# %%
X_train.describe(include=object).T.iloc[:10]
# Out:
#              count unique     top freq
# MSZoning       978      5      RL  767
# Street         978      2    Pave  974
# Alley           60      2    Grvl   32
# LotShape       978      4     Reg  612
# LandContour    978      4     Lvl  880
# Utilities      978      2  AllPub  977
# LotConfig      978      5  Inside  705
# LandSlope      978      3     Gtl  926
# Neighborhood   978     25   NAmes  146
# Condition1     978      9    Norm  838

# %% [markdown]
# Handling null values

# %%
more_than_zero_null_values = X_train.isnull().sum()>0

X_train.isnull().sum()[more_than_zero_null_values]
# Out:
# LotFrontage     181
# Alley           918
# MasVnrType        6
# MasVnrArea        6
# BsmtQual         29
# BsmtCond         29
# BsmtExposure     29
# BsmtFinType1     29
# BsmtFinType2     30
# FireplaceQu     460
# GarageType       56
# GarageYrBlt      56
# GarageFinish     56
# GarageQual       56
# GarageCond       56
# PoolQC          974
# Fence           796
# MiscFeature     945
# dtype: int64

# %% [markdown]
# 19 columns have more than 0 Null values\
# Let's figure out the numerical features and categorical features

# %%
num_features = X_train.select_dtypes(include = 'number').columns.tolist()
print(f"The numerical features are {len(num_features)}.")
print(f"They are {', '.join(num_features)}.")
# Out:
# The numerical features are 37.
# They are Id, MSSubClass, LotFrontage, LotArea, OverallQual, OverallCond, YearBuilt, YearRemodAdd, MasVnrArea, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, TotRmsAbvGrd, Fireplaces, GarageYrBlt, GarageCars, GarageArea, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold.

# %%
cat_features =  X_train.select_dtypes(exclude = 'number').columns.tolist()
print(f"The categorical features are {len(cat_features)}.")
print(f"They are {', '.join(cat_features)}.")
# Out:
# The categorical features are 43.
# They are MSZoning, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinType2, Heating, HeatingQC, CentralAir, Electrical, KitchenQual, Functional, FireplaceQu, GarageType, GarageFinish, GarageQual, GarageCond, PavedDrive, PoolQC, Fence, MiscFeature, SaleType, SaleCondition.

# %% [markdown]
# I will use simple imputer for the missing values and the MinMaxScaler for the feature scaling.\
# Simple Imputer will be used and the mode will be filled in the missing categorical features\
# I will use Pipeline because it is a new and interesting technique.

# %%
numeric_pipeline = Pipeline(
    steps = [
        ('Numerical imputer', SimpleImputer(strategy='mean')),
        ('numerical scaler', MinMaxScaler()) 
    ])

categorical_pipeline = Pipeline(
    steps = [
        ('categorical imputer', SimpleImputer(strategy='most_frequent')),
        ('categorical one-hot', OneHotEncoder(handle_unknown='ignore',sparse = False)) 
    ])

# %% [markdown]
# Using column transformer is needed in order to avoid the fit and transform for both the pipeline above

# %%
full_transformer = ColumnTransformer(transformers=[
    ('number', numeric_pipeline, num_features),
    ('category', categorical_pipeline, cat_features)
])

# %%
full_transformer.fit_transform(X_train)
# Out:
# array([[0.10089224, 0.23529412, 0.29768464, ..., 0.        , 1.        ,
#         0.        ],
#        [0.31708991, 0.        , 0.24223602, ..., 0.        , 1.        ,
#         0.        ],
#        [0.79341112, 0.35294118, 0.39751553, ..., 0.        , 1.        ,
#         0.        ],
#        ...,
#        [0.39670556, 0.82352941, 0.08074534, ..., 0.        , 0.        ,
#         0.        ],
#        [0.26835964, 0.23529412, 0.31055901, ..., 0.        , 1.        ,
#         0.        ],
#        [0.71654084, 0.        , 0.36645963, ..., 0.        , 1.        ,
#         0.        ]])

# %% [markdown]
# Lasso model (L1 regularization)

# %%
lasso_model = Lasso(alpha = 0.1)

lasso_pipeline = Pipeline(
    steps = [
        ('preprocessing', full_transformer),
        ('model',lasso_model)
    ])

# %%
_ = lasso_pipeline.fit(X_train, y_train)
# Out:
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.352e+10, tolerance: 6.146e+08
#   model = cd_fast.enet_coordinate_descent(

# %%
predictions = lasso_pipeline.predict(X_valid)

# %%
mean_absolute_error(y_valid,predictions)
# Out:
# 18220.90578423801

# %%
r2_score(y_valid,predictions)
# Out:
# 0.760180429884422

# %% [markdown]
# Hyperparameter Optimization

# %%
parameters_grid = {'model__alpha':np.arange(0,1,0.02)}

grid_search = GridSearchCV(
    lasso_pipeline,
    parameters_grid,
    cv= 10, 
    scoring = 'neg_mean_absolute_error'
)
_ = grid_search.fit(X_train,y_train)
# Out:
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\pipeline.py:382: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.632e+11, tolerance: 5.410e+08 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\pipeline.py:382: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.812e+11, tolerance: 5.221e+08 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\pipeline.py:382: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.435e+11, tolerance: 5.753e+08 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\pipeline.py:382: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.401e+11, tolerance: 5.389e+08 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\pipeline.py:382: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.578e+11, tolerance: 5.528e+08 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\pipeline.py:382: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.692e+11, tolerance: 5.376e+08 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\pipeline.py:382: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.788e+11, tolerance: 5.777e+08 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\pipeline.py:382: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.776e+11, tolerance: 5.502e+08 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\pipeline.py:382: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.860e+11, tolerance: 5.674e+08 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\pipeline.py:382: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.755e+11, tolerance: 5.677e+08 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.238e+10, tolerance: 5.410e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.462e+10, tolerance: 5.221e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.273e+10, tolerance: 5.753e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.739e+10, tolerance: 5.389e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.131e+10, tolerance: 5.528e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.906e+10, tolerance: 5.376e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.945e+10, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.846e+10, tolerance: 5.502e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.112e+10, tolerance: 5.674e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.047e+10, tolerance: 5.677e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.242e+10, tolerance: 5.410e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.899e+10, tolerance: 5.221e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.274e+10, tolerance: 5.753e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.726e+10, tolerance: 5.389e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.502e+10, tolerance: 5.528e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.909e+10, tolerance: 5.376e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.636e+10, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.818e+10, tolerance: 5.502e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.772e+10, tolerance: 5.674e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.054e+10, tolerance: 5.677e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.246e+10, tolerance: 5.410e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.152e+10, tolerance: 5.221e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.280e+10, tolerance: 5.753e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.805e+10, tolerance: 5.389e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.503e+10, tolerance: 5.528e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.884e+10, tolerance: 5.376e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.210e+10, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.866e+10, tolerance: 5.502e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.776e+10, tolerance: 5.674e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.825e+10, tolerance: 5.677e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.250e+10, tolerance: 5.410e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.856e+10, tolerance: 5.221e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.283e+10, tolerance: 5.753e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.795e+10, tolerance: 5.389e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.508e+10, tolerance: 5.528e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.159e+10, tolerance: 5.376e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.183e+10, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.863e+10, tolerance: 5.502e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.758e+10, tolerance: 5.674e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.755e+10, tolerance: 5.677e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.170e+10, tolerance: 5.410e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.039e+10, tolerance: 5.221e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.289e+10, tolerance: 5.753e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.807e+10, tolerance: 5.389e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.712e+10, tolerance: 5.528e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.739e+10, tolerance: 5.376e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.242e+10, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.038e+10, tolerance: 5.502e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.856e+10, tolerance: 5.674e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.742e+10, tolerance: 5.677e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.275e+10, tolerance: 5.410e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.089e+10, tolerance: 5.221e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.292e+10, tolerance: 5.753e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.806e+10, tolerance: 5.389e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.711e+10, tolerance: 5.528e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.747e+10, tolerance: 5.376e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.226e+10, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.034e+10, tolerance: 5.502e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.178e+10, tolerance: 5.674e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.492e+10, tolerance: 5.677e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.715e+10, tolerance: 5.410e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.042e+10, tolerance: 5.221e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.297e+10, tolerance: 5.753e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.819e+10, tolerance: 5.389e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.719e+10, tolerance: 5.528e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.664e+10, tolerance: 5.376e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.429e+10, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.051e+10, tolerance: 5.502e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.163e+10, tolerance: 5.674e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.833e+10, tolerance: 5.677e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.266e+10, tolerance: 5.410e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.063e+10, tolerance: 5.221e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.302e+10, tolerance: 5.753e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.824e+10, tolerance: 5.389e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.720e+10, tolerance: 5.528e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.781e+10, tolerance: 5.376e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.222e+10, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.038e+10, tolerance: 5.502e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.113e+10, tolerance: 5.674e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.836e+10, tolerance: 5.677e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.270e+10, tolerance: 5.410e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.066e+10, tolerance: 5.221e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.015e+10, tolerance: 5.753e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.829e+10, tolerance: 5.389e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.712e+10, tolerance: 5.528e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.581e+10, tolerance: 5.376e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.243e+10, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.045e+10, tolerance: 5.502e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.258e+10, tolerance: 5.674e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.838e+10, tolerance: 5.677e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.839e+10, tolerance: 5.410e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.065e+10, tolerance: 5.221e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.310e+10, tolerance: 5.753e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.832e+10, tolerance: 5.389e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.725e+10, tolerance: 5.528e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.407e+10, tolerance: 5.376e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.235e+10, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.056e+10, tolerance: 5.502e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.232e+10, tolerance: 5.674e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.532e+10, tolerance: 5.677e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.277e+10, tolerance: 5.410e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.071e+10, tolerance: 5.221e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.324e+10, tolerance: 5.753e+08
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.492e+09, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.404e+09, tolerance: 5.502e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.282e+09, tolerance: 5.674e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.783e+09, tolerance: 5.410e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.829e+09, tolerance: 5.221e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.399e+09, tolerance: 5.753e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.094e+09, tolerance: 5.528e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.677e+09, tolerance: 5.376e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.505e+09, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.418e+09, tolerance: 5.502e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.296e+09, tolerance: 5.674e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.798e+09, tolerance: 5.410e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.841e+09, tolerance: 5.221e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.423e+09, tolerance: 5.753e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.075e+09, tolerance: 5.528e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.687e+09, tolerance: 5.376e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.517e+09, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.432e+09, tolerance: 5.502e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.310e+09, tolerance: 5.674e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.812e+09, tolerance: 5.410e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.852e+09, tolerance: 5.221e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.488e+09, tolerance: 5.753e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.064e+09, tolerance: 5.528e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.697e+09, tolerance: 5.376e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.530e+09, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.447e+09, tolerance: 5.502e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.324e+09, tolerance: 5.674e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.826e+09, tolerance: 5.410e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.863e+09, tolerance: 5.221e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.643e+09, tolerance: 5.753e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.058e+09, tolerance: 5.528e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.709e+09, tolerance: 5.376e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.543e+09, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.461e+09, tolerance: 5.502e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.338e+09, tolerance: 5.674e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.954e+09, tolerance: 5.410e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.875e+09, tolerance: 5.221e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.542e+09, tolerance: 5.753e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.054e+09, tolerance: 5.528e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.720e+09, tolerance: 5.376e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.556e+09, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.475e+09, tolerance: 5.502e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.352e+09, tolerance: 5.674e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.488e+09, tolerance: 6.146e+08
#   model = cd_fast.enet_coordinate_descent(

# %%
print(f'The best alpha value is {grid_search.best_params_}')
# Out:
# The best alpha value is {'model__alpha': 0.98}

# %%
print(f'The best score is {abs(grid_search.best_score_)}')
# Out:
# The best score is 18443.656766920954

# %% [markdown]
# Try with more parameters

# %%
parameters_grid = {'model__alpha':np.arange(1,200,5)}

grid_search = GridSearchCV(
    lasso_pipeline,
    parameters_grid,
    cv= 10, 
    scoring = 'neg_mean_absolute_error'
)
_ = grid_search.fit(X_train,y_train)
# Out:
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.570e+09, tolerance: 5.410e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.886e+09, tolerance: 5.221e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.124e+09, tolerance: 5.753e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.053e+09, tolerance: 5.528e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.732e+09, tolerance: 5.376e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.913e+09, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.490e+09, tolerance: 5.502e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\as\anaconda3\envs\baseREC\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.367e+09, tolerance: 5.674e+08
#   model = cd_fast.enet_coordinate_descent(

# %%
print(f'The best alpha value is {grid_search.best_params_}')
# Out:
# The best alpha value is {'model__alpha': 96}

# %%
print(f'The best score is {abs(grid_search.best_score_)}')
# Out:
# The best score is 16747.366502908117

# %% [markdown]
# Ridge model (L2 regularization)

# %%
ridge_model = Ridge(alpha = 0.1)

ridge_pipeline = Pipeline(
    steps = [
        ('preprocessing', full_transformer),
        ('model',ridge_model)
    ])

# %%
_ = ridge_pipeline.fit(X_train, y_train)

# %%
predictions = ridge_pipeline.predict(X_valid)

# %%
mean_absolute_error(y_valid,predictions)
# Out:
# 18185.32918987934

# %%
r2_score(y_valid,predictions)
# Out:
# 0.7637747258600046

# %% [markdown]
# Hyperparameter optimisation

# %%
parameters_grid = {'model__alpha':np.arange(1,200,5)}

grid_search = GridSearchCV(
    ridge_pipeline,
    parameters_grid,
    cv= 10, 
    scoring = 'neg_mean_absolute_error'
)
_ = grid_search.fit(X_train,y_train)

# %%
print(f'The best alpha value is {grid_search.best_params_}')
# Out:
# The best alpha value is {'model__alpha': 6}

# %%
print(f'The best score is {abs(grid_search.best_score_)}')
# Out:
# The best score is 17444.619350162542
